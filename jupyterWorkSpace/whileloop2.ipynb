# %%
while condtion :
    code

# %%
while condition 
 if condition:
     break

# %%
ask use to enter any five values and if sum is greater than 100 than stop

# %% [markdown]
# ** list of students, if you find partiuclar studnet than stop  the loop

# %%
l="siva","rama","alex"
x=1
while x<=len(l):

    n=input('enter your name :')

    if n=="siva":
        print(x)
        break
    x=x+1
# Out:
# enter your name : max
# enter your name : alex
# enter your name : siva
# 3

# %%
l="siva","rama","alex"
x=1
while True:

    n=input('enter your name :')

    if n=="siva":
        print(x)
        break
    x=x+1
# Out:
# enter your name : max
# enter your name : mac
# enter your name : max
# enter your name : maas
# enter your name : alex
# enter your name : siva
# 6

# %%
--ask user to enter the any values where the num is >100, stop 
-- aldi ask when ever sum is more than 1000 stop billing

# %%
s=0

while True:
    n = eval(input("enter the value:"))
    s= s+n
    print(s)
    if s>1000:
        break
# Out:
# enter the value: 700
# 700
# enter the value: 80
# 780
# enter the value: 300
# 1080

# %%
s=0

while True:
    print("enter the values and once entires are complete click on #")
    n = eval(input("enter the value:"))
    s= s+n
    print(s)
    if s>1000:
        break

# %% [markdown]
# *remove all the 10 from list by maintaining the order of list without using set

# %%
l=[10,10,20,40,10,90]

while l==10:
    l.remove(10)

print(l)

##wrong
# Out:
# [10, 10, 20, 40, 10, 90]

# %%
l1 =[1,2,3,4]
l2 =[2,3,5]

#all values in list 2

##l2=l1+l2
##print(l2)

while l
# Out:
# [1, 2, 3, 4, 2, 3, 5]

# %%
l=[10,10,10,20,30,10]

new_list=[]
## remove all 10 without set 

##method 1
for items in l:
 if(items!=10):
  new_list.append(items)
print(new_list)
# Out:
# [20, 30]
# [10, 10, 20, 30, 10]
# [10, 20, 30, 10]
# [20, 30, 10]
# [20, 30]

# %%
##method 2 
m=[10,10,10,20,30,10]

while 10 in m:
    m.remove(10)
    
print(m)
# Out:
# [20, 30]

# %%
l=[10,20,30,40,50]

##extract value index 0 1 5 save in list
new_list=[]
index =0
for items in l:
    if (index==0 or index==1 or index==5):
        new_list.append(items)

    index=index+1
    
print(new_list)
##exravt value of index [0,1,1,1,4,5] and save is list
# Out:
# [10, 20]

# %%
l=[10,20,30,40,50]
## add 5 for every value in list save in list
new=[]
for items in l:
    new.append(items+5)

print(new)
# Out:
# [15, 25, 35, 45, 55]

# %%
list1=[20,30,40]
list2=[100,200,300]

##value of list1 should be to the corresponding value of list2 [ 120,230,430]

# %%
l=[10,20,30,40,50,60]
##extract the values of index [0,1,1,1,4] save in list 

indices=[0,1,1,1,4]
new_l=[]

for i in indices:
    print(i)
   ## print(indices)
    value=l[i]
    new_l.append(value)

print(new_l)
# Out:
# 0
# 1
# 1
# 1
# 4
# [10, 20, 20, 20, 50]
