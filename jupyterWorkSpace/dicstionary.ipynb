# %%
## dictionary

l=[10,11,12]
print(l)

#key value (key should be immutable ,value can be any datatype

d={1.5:50}
print(d)

k={True:50}
print (k)

### try with tapple
d={(1,2):50}
print(d)
# Out:
# [10, 11, 12]
# {1.5: 50}
# {True: 50}
# {(1, 2): 50}
