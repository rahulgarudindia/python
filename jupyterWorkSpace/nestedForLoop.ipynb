# %%
### break
l=[1,20,25,4,8,20]
n=[]
for i in l:
  
    if i==4:
        break;
    n.append(i+5)

print(n)
# Out:
# [6, 25, 30]

# %%
##continue
l=[1,20,25,4,8,20]
n=[]
for i in l:
   
    if i==4:
        print(i)
        print(n)
        continue;
        print(i)
        print(n)
    n.append(i+5)

print(n)
# Out:
# 4
# [6, 25, 30]
# [6, 25, 30, 13, 25]

# %%
### nested loops 
for i in [1,2]:
    for j in [4,5]:  
         print(i,j)
# Out:
# 1 4
# 1 5
# 2 4
# 2 5

# %%
### 
for i in l[1,2]:
    a=20
    b=i+10
    print(a)
    print(b)
  #  for j in(4,5):
   #     c=b+j
    #    print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ###
# ----> 2 for i in l(1,2):
#       3     a=20
#       4     b=i+10
#
# TypeError: 'list' object is not callable
