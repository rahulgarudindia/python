# %%
##


s = {2,3,4,5,6,7}
s.add(10)
print(s)
# Out:
# {2, 3, 4, 5, 6, 7, 10}

# %%
### remore the 10

s = {2,3,4,5,6,7,10}
s.remove(10)

print(s)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
### pop 


s = {2,3,4,5,6,7,10}
s.pop()
print(s)
s.discard(7)
print(s)
# Out:
# {3, 4, 5, 6, 7, 10}
# {3, 4, 5, 6, 10}

# %% [markdown]
# convert to set to list
# list to set

# %%
s = {2,3,4,5,6,7,10}
l=[s]
print(l)
# Out:
# [{2, 3, 4, 5, 6, 7, 10}]

# %%
### combine two set { }

A={2,3,4}
B={5,6,7}
C={2,7,4}
##print("union",A.union(B))
print(A)
print(B)
print("intersection",A.intersection(B))
print(" insersection", A.intersection(C))
# Out:
# {2, 3, 4}
# {5, 6, 7}
# intersection set()
#  insersection {2, 4}

# %%
### A set intersection and intersection_update with set B
A={2,3,4,5}
B={5,6,7,9,10,5}
C={2,7,4}

##print(A.intersection(B))
##print(A.intersection_update(B))
print(A.intersection_update(B))
print(B.intersection_update(A))
#print(B)
#print(A)
# Out:
# None
# None
