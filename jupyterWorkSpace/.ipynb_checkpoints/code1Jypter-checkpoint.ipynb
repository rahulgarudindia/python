# %%
x= 10
print(x);
# Out:
# 10

# %%
perform addition of 2 digits

# %% [markdown]
# x=10;
# x=x+1;
# print(x)

# %% [markdown]
# if else

# %% [markdown]
# Please perform simple compare operation

# %%
x=2 
y=3
if(x>y):
    print("true")
else:
    print("false");
# Out:
# false

# %% [markdown]
# check value in list and print

# %%
l=[1,5,4,6]
if 5 in l:
    print("5 is present")
# Out:
# 5 is present

# %% [markdown]
# practice formating
#
#
# # Heading
#
# **bold**

# %% [markdown]
# Practice formating
#
# # heading
#
# *bold*

# %%
#perform if else elif sample code #

score=2.5

if score>1:
    print("one")
elif score<3:
    print("two")
else:
    print("you in else")
# Out:
# one

# %% [markdown]
# this is markdown section and perfor if else compare
#
# # heading
#
# *bold*

# %%
x=7
if x>5:
    print("A")

elif x>6:
    print("B")
# Out:
# A

# %% [markdown]
# ##perform if else if else example

# %%
if test==test:
    print("test")
    if one==one:
            print("one")
    else:
            print("two")

else:
   print("else")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 if test==test:
#       2     print("test")
#       3     if one==one:
#
# NameError: name 'test' is not defined
