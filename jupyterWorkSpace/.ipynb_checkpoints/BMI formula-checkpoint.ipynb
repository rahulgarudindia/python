# %%
#convert BMI for user input
#take wegith form user
#take hieght from user 

weight =eval(input(" enter the weight "))
height =eval(input (" enter the height "))
BMI=weight/height**2

print("BMI", BMI)
# Out:
#  enter the weight  100
#  enter the height  3
# BMI 11.11111111111111
