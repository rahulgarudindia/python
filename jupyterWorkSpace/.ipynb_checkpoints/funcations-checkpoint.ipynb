# %% [markdown]
# ## write funcation to return the sqare##

# %%
def sqaure(x):
    return x*x

sqaure(2)
# Out:
# 4

# %% [markdown]
# ## define fucantion with one argument and two argument ##

# %%
def oneArg(x):
    print(x)

oneArg("rhl")

def oneArg(x,y):
    print(x)
    print(y)

oneArg("rhl","start")
# Out:
# rhl
# rhl
# start
