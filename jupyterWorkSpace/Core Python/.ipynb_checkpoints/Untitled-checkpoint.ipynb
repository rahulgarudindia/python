# %%
# user will gives 3 numbers identify the largest

#ask numbers
# 10, 50, 19 


numb1 = eval(input("enter  1st number:"))
numb2= eval(input("enter 2nd number:"))
numb3= eval(input("enter 3rd number"))

if(numb1>numb2 and numb1>numb3):
  print("numb1 ", numb1);
# Out:
# enter  1st number: 10
# enter 2nd number: 3
# enter 3rd number 2
# numb1  10
